# %% [markdown]
# # EDA (Exploratory data anaylsis)
# This notebook is used to explore the data and get a better understanding of the data

# %% [markdown]
# ### Super ways to conduct EDA in one go

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.2.0-py2.py3-none-any.whl (352 kB)
# Collecting seaborn<0.13,>=0.10.1
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting pandas!=1.4.0,<2,>1.1
#   Using cached pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
# Collecting wordcloud>=1.9.1
#   Using cached wordcloud-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# Collecting dacite>=1.8
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Collecting phik<0.13,>=0.11.1
#   Using cached phik-0.12.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
# Collecting numpy<1.24,>=1.16.0
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 10 kB/s  eta 0:00:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/lib/python3/dist-packages (from ydata-profiling) (5.3.1)
# Collecting jinja2<3.2,>=2.11.1
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting tqdm<5,>=4.48.2
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting multimethod<2,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: matplotlib<4,>=3.2 in /home/mysterious/.local/lib/python3.8/site-packages (from ydata-profiling) (3.7.1)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 622 kB/s eta 0:00:01
# Collecting scipy<1.11,>=1.4.1
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 3.6 kB/s eta 0:00:01    |▏                               | 225 kB 614 kB/s eta 0:00:56
# Collecting typeguard<3,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting pydantic<2,>=1.8.1
#   Using cached pydantic-1.10.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting statsmodels<1,>=0.13.2
#   Using cached statsmodels-0.14.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Collecting requests<3,>=2.24.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 13 kB/s  eta 0:00:01
# Collecting imagehash==4.3.1
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/mysterious/.local/lib/python3.8/site-packages (from pandas!=1.4.0,<2,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mysterious/.local/lib/python3.8/site-packages (from pandas!=1.4.0,<2,>1.1->ydata-profiling) (2.8.2)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from wordcloud>=1.9.1->ydata-profiling) (7.0.0)
# Collecting joblib>=0.14.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 12 kB/s  eta 0:00:01
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: cycler>=0.10 in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (4.40.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mysterious/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.1.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 2.3 kB/s eta 0:00:01
# Collecting networkx>=2.4
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 367 kB/s eta 0:00:01
# Collecting attrs>=19.3.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 75 kB/s  eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/mysterious/.local/lib/python3.8/site-packages (from pydantic<2,>=1.8.1->ydata-profiling) (4.6.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 746 kB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2019.11.28)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (1.25.8)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      |████████████████████████████████| 195 kB 905 kB/s eta 0:00:01
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 590 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas!=1.4.0,<2,>1.1->ydata-profiling) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/mysterious/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib<4,>=3.2->ydata-profiling) (3.15.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27084 sha256=3b036d9ddfd42f2ece3b4d8330cd4db3b6f3c2a8819a95c346dd655e6054d4dd
#   Stored in directory: /home/mysterious/.cache/pip/wheels/23/14/6e/4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
# Successfully built htmlmin
# Installing collected packages: numpy, pandas, seaborn, wordcloud, dacite, joblib, scipy, phik, MarkupSafe, jinja2, tqdm, multimethod, htmlmin, tangled-up-in-unicode, networkx, attrs, PyWavelets, imagehash, visions, typeguard, pydantic, patsy, statsmodels, charset-normalizer, requests, ydata-profiling
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.2
#     Uninstalling pandas-2.0.2:
#       Successfully uninstalled pandas-2.0.2
# Successfully installed MarkupSafe-2.1.3 PyWavelets-1.4.1 attrs-23.1.0 charset-normalizer-3.1.0 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 jinja2-3.1.2 joblib-1.2.0 multimethod-1.9.1 networkx-3.1 numpy-1.23.5 pandas-1.5.3 patsy-0.5.3 phik-0.12.3 pydantic-1.10.9 requests-2.31.0 scipy-1.10.1 seaborn-0.12.2 statsmodels-0.14.0 tangled-up-in-unicode-0.2.0 tqdm-4.65.0 typeguard-2.13.3 visions-0.7.5 wordcloud-1.9.2 ydata-profiling-4.2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp
from pandas_profiling import ProfileReport

# %%
# importing dataset
df = pd.read_csv('/media/mysterious/Resources/DataSets/Google-Playstore.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # importing dataset
# ----> 2 df = pd.read_csv('/media/mysterious/Resources/DataSets/Google-Playstore.csv')
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
# Failed to interrupt the Kernel.
#
# Unable to start Kernel 'Python 3.8.10' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# profile report generation
report = ProfileReport(df)

# saving report
report.to_file('report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]Summarize dataset: 100%|██████████| 438/438 [03:07<00:00,  2.33it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:22<00:00, 22.12s/it]
# Render HTML: 100%|██████████| 1/1 [00:14<00:00, 14.19s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]

# %% [markdown]
# ## Skimpy

# %%
from skimpy import skim
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 5735   │ │ float64     │ 20    │                                                          │
# │ │ Number of columns │ 28     │ │ int64       │ 8     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column_name     ┃ NA     ┃ NA %    ┃ mean    ┃ sd      ┃ p0      ┃ p25     ┃ p75     ┃ p100     ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ SEQN            │      0 │       0 │   89000 │    2900 │   84000 │   86000 │   91000 │    94000 │  ██████  │  │
# │ │ ALQ101          │    530 │     9.2 │     1.3 │    0.51 │       1 │       1 │       2 │        9 │    █     │  │
# │ │ ALQ110          │   4000 │      70 │     1.6 │    0.62 │       1 │       1 │       2 │        9 │    █     │  │
# │ │ ALQ130          │   2400 │      41 │     3.9 │      34 │       1 │       1 │       3 │     1000 │    █     │  │
# │ │ SMQ020          │      0 │       0 │     1.6 │    0.57 │       1 │       1 │       2 │        9 │    █     │  │
# │ │ RIAGENDR        │      0 │       0 │     1.5 │     0.5 │       1 │       1 │       2 │        2 │  ▇    █  │  │
# │ │ RIDAGEYR        │      0 │       0 │      48 │      18 │      18 │      32 │      63 │       80 │  █▇▇▇▇▇  │  │
# │ │ RIDRETH1        │      0 │       0 │       3 │     1.3 │       1 │       2 │       4 │        5 │  ▄▃ █▅▄  │  │
# │ │ DMDCITZN        │      1 │   0.017 │     1.2 │    0.49 │       1 │       1 │       1 │        9 │    █     │  │
# │ │ DMDEDUC2        │    260 │     4.6 │     3.4 │     1.3 │       1 │       3 │     4.8 │        9 │   ▆▆█▇   │  │
# │ │ DMDMARTL        │    260 │     4.6 │     2.6 │     2.4 │       1 │       1 │       5 │       77 │    █     │  │
# │ │ DMDHHSIZ        │      0 │       0 │     3.3 │     1.7 │       1 │       2 │       5 │        7 │  ▄█▅▅▄▄  │  │
# │ │ WTINT2YR        │      0 │       0 │   40000 │   39000 │    5300 │   17000 │   43000 │   230000 │   █▁▁▁   │  │
# │ │ SDMVPSU         │      0 │       0 │     1.5 │     0.5 │       1 │       1 │       2 │        2 │  █    █  │  │
# │ │ SDMVSTRA        │      0 │       0 │     130 │     4.2 │     120 │     120 │     130 │      130 │  ▇▅▅▇▅█  │  │
# │ │ INDFMPIR        │    600 │      10 │     2.4 │     1.6 │       0 │     1.1 │     3.7 │        5 │  ▅█▅▄▂▇  │  │
# │ │ BPXSY1          │    330 │     5.8 │     130 │      18 │      82 │     110 │     130 │      240 │   ▂█▃▁   │  │
# │ │ BPXDI1          │    330 │     5.8 │      70 │      13 │       0 │      62 │      78 │      120 │    ▂█▃   │  │
# │ │ BPXSY2          │    200 │     3.5 │     120 │      19 │      84 │     110 │     130 │      240 │   ▃█▃▁   │  │
# │ │ BPXDI2          │    200 │     3.5 │      69 │      13 │       0 │      62 │      78 │      140 │     █▇   │  │
# │ │ BMXWT           │     69 │     1.2 │      81 │      22 │      32 │      66 │      93 │      200 │   ▂█▄▁   │  │
# │ │ BMXHT           │     62 │     1.1 │     170 │      10 │     130 │     160 │     170 │      200 │   ▂██▂   │  │
# │ │ BMXBMI          │     73 │     1.3 │      29 │     7.1 │      14 │      24 │      33 │       67 │   ▃█▃▁   │  │
# │ │ BMXLEG          │    390 │     6.8 │      39 │     3.9 │      26 │      36 │      41 │       52 │   ▃██▃   │  │
# │ │ BMXARML         │    310 │     5.4 │      37 │     2.8 │      28 │      35 │      39 │       47 │   ▄█▇▂   │  │
# │ │ BMXARMC         │    310 │     5.4 │      33 │     5.3 │      17 │      30 │      36 │       58 │    ▆█▂   │  │
# │ │ BMXWAIST        │    370 │     6.4 │     100 │      17 │      59 │      88 │     110 │      170 │  ▂▇█▃▁   │  │
# │ │ HIQ210          │   1000 │      17 │     1.9 │    0.41 │       1 │       2 │       2 │        9 │    █     │  │
# │ └─────────────────┴────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴──────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-2.16.0-py2.py3-none-any.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 45 kB/s  eta 0:00:01
# Requirement already satisfied: numpy; python_version >= "3.0" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (1.23.5)
# Collecting strsimpy
#   Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 106 kB/s eta 0:00:01
# Requirement already satisfied: future>=0.14.0 in /usr/lib/python3/dist-packages (from dtale) (0.18.2)
# Requirement already satisfied: networkx; python_version > "3.7" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (3.1)
# Collecting Flask; python_version >= "3.8"
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 322 kB/s eta 0:00:01
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      |████████████████████████████████| 642 kB 919 kB/s eta 0:00:01
# Collecting beautifulsoup4; python_version > "3.0"
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      |████████████████████████████████| 142 kB 392 kB/s eta 0:00:01
# Collecting lz4; python_version > "3.6"
#   Downloading lz4-4.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 274 kB/s eta 0:00:01
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      |████████████████████████████████| 79.9 MB 43 kB/s  eta 0:00:01��███████████████   | 72.3 MB 492 kB/s eta 0:00:16
# Collecting matplotlib<=3.6.0; python_version == "3.8"
#   Downloading matplotlib-3.6.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      |████████████████████████████████| 9.4 MB 555 kB/s eta 0:00:01
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from dtale) (1.14.0)
# Requirement already satisfied: certifi; python_version > "3.0" in /usr/lib/python3/dist-packages (from dtale) (2019.11.28)
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 118 kB/s eta 0:00:01
# Requirement already satisfied: scikit-learn; python_version > "3.7" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (1.2.2)
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests; python_version >= "3.7" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (2.31.0)
# Collecting openpyxl!=3.2.0b1; python_version >= "3.0"
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      |████████████████████████████████| 249 kB 813 kB/s eta 0:00:01
# Collecting flask-ngrok; python_version > "3.0"
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: pandas in /home/solu/.local/lib/python3.8/site-packages (from dtale) (1.5.3)
# Requirement already satisfied: cycler; python_version > "3.0" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (0.11.0)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 352 kB/s eta 0:00:01
# Collecting itsdangerous; python_version >= "3.7"
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: statsmodels; python_version > "3.7" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (0.14.0)
# Collecting missingno<=0.4.2
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Collecting et-xmlfile; python_version >= "3.6"
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting scipy<=1.9.3; python_version >= "3.8"
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      |████████████████████████████████| 33.8 MB 74 kB/s  eta 0:00:01
# Collecting dash; python_version >= "3.6"
#   Downloading dash-2.10.2-py3-none-any.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 47 kB/s  eta 0:00:01
# Requirement already satisfied: seaborn; python_version > "3.6" in /home/solu/.local/lib/python3.8/site-packages (from dtale) (0.12.2)
# Collecting dash-bootstrap-components<=1.3.1; python_version > "3.6"
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 932 kB/s eta 0:00:01
# Collecting plotly; python_version >= "3.6"
#   Downloading plotly-5.14.1-py2.py3-none-any.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 89 kB/s  eta 0:00:01                 | 4.1 MB 610 kB/s eta 0:00:1916               | 5.1 MB 692 kB/s eta 0:00:15��█████████▋                  | 6.5 MB 453 kB/s eta 0:00:20 eta 0:00:15�█████████████████           | 10.1 MB 393 kB/s eta 0:00:14
# Collecting xarray; python_version >= "3.0"
#   Downloading xarray-2023.1.0-py3-none-any.whl (973 kB)
#      |████████████████████████████████| 973 kB 780 kB/s eta 0:00:01
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting Werkzeug>=2.3.3
#   Downloading Werkzeug-2.3.4-py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 527 kB/s eta 0:00:01
# Requirement already satisfied: Jinja2>=3.1.2 in /home/solu/.local/lib/python3.8/site-packages (from Flask; python_version >= "3.8"->dtale) (3.1.2)
# Requirement already satisfied: click>=8.1.3 in /home/solu/.local/lib/python3.8/site-packages (from Flask; python_version >= "3.8"->dtale) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in /home/solu/.local/lib/python3.8/site-packages (from Flask; python_version >= "3.8"->dtale) (6.6.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/solu/.local/lib/python3.8/site-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/solu/.local/lib/python3.8/site-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/solu/.local/lib/python3.8/site-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (4.39.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/solu/.local/lib/python3.8/site-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/solu/.local/lib/python3.8/site-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (7.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/solu/.local/lib/python3.8/site-packages (from matplotlib<=3.6.0; python_version == "3.8"->dtale) (1.4.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/solu/.local/lib/python3.8/site-packages (from scikit-learn; python_version > "3.7"->dtale) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/solu/.local/lib/python3.8/site-packages (from scikit-learn; python_version > "3.7"->dtale) (3.1.0)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 673 kB/s eta 0:00:01
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests; python_version >= "3.7"->dtale) (1.25.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests; python_version >= "3.7"->dtale) (2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/solu/.local/lib/python3.8/site-packages (from requests; python_version >= "3.7"->dtale) (3.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/solu/.local/lib/python3.8/site-packages (from pandas->dtale) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/solu/.local/lib/python3.8/site-packages (from statsmodels; python_version > "3.7"->dtale) (0.5.3)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/solu/.local/lib/python3.8/site-packages (from Werkzeug>=2.3.3->Flask; python_version >= "3.8"->dtale) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /home/solu/.local/lib/python3.8/site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask; python_version >= "3.8"->dtale) (3.15.0)
# Building wheels for collected packages: dash-daq, dash-colorscales
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669702 sha256=d15fd7de31cac6e07a0ce287e6f890508b7cb83b400674bd02622c97bac86f4c
#   Stored in directory: /home/solu/.cache/pip/wheels/00/35/e5/57e90f10c529601c6627400513cb65dd5adb09752411f5a050
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62597 sha256=dc8de1d226fb0a87c308cacbdbb2d4aaa1f686a691dc607125ec4ef12f696da9
#   Stored in directory: /home/solu/.cache/pip/wheels/fe/33/33/172dbfe1efc739352828854a113df599a428b58f68ed0c4f75
# Successfully built dash-daq dash-colorscales
# ERROR: dash 2.10.2 has requirement Flask<2.3.0,>=1.0.4, but you'll have flask 2.3.2 which is incompatible.
# ERROR: dash 2.10.2 has requirement Werkzeug<2.3.0, but you'll have werkzeug 2.3.4 which is incompatible.
# Installing collected packages: strsimpy, blinker, Werkzeug, itsdangerous, Flask, dash-html-components, dash-core-components, tenacity, plotly, dash-table, dash, dash-daq, soupsieve, beautifulsoup4, lz4, kaleido, matplotlib, dash-colorscales, brotli, Flask-Compress, et-xmlfile, openpyxl, flask-ngrok, xlrd, scipy, missingno, dash-bootstrap-components, xarray, squarify, dtale
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Successfully installed Flask-2.3.2 Flask-Compress-1.13 Werkzeug-2.3.4 beautifulsoup4-4.12.2 blinker-1.6.2 brotli-1.0.9 dash-2.10.2 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-2.16.0 et-xmlfile-1.1.0 flask-ngrok-0.0.25 itsdangerous-2.1.2 kaleido-0.2.1 lz4-4.3.2 matplotlib-3.6.0 missingno-0.4.2 openpyxl-3.1.2 plotly-5.14.1 scipy-1.9.3 soupsieve-2.4.1 squarify-0.4.3 strsimpy-0.2.1 tenacity-8.2.2 xarray-2023.1.0 xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale as dt
diamonds = sns.load_dataset('diamonds')
dt.show(diamonds)
# dt.show(df)
