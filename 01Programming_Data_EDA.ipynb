# %% [markdown]
# #### Following are the steps to be followed:
# 1. Understand the data
# 2. Clean the data
# 3. Find patterns in the data

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
languages = pd.read_csv('/media/mysterious/Resources/DataSets/Popularity_of_Programming_Languages_from_2004_to_2023.csv')
languages.head()
# Out:
#              Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0       July 2004  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1     August 2004  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2  September 2004  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3    October 2004  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4   November 2004  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 0    0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 1    0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2    0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 3    0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 4    0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
#    TypeScript   VBA  Visual Basic
# 0         0.0  1.43          8.50
# 1         0.0  1.45          8.51
# ...

# %%
languages.tail()
# Out:
#               Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal    Go  \
# 222   January 2023  0.46  0.85   6.84  6.93   0.39  0.82           0.00  1.92
# 223  February 2023  0.46  0.89   6.84  6.92   0.37  0.82           0.02  1.93
# 224     March 2023  0.46  0.93   6.86  6.81   0.37  0.80           0.09  1.90
# 225     April 2023  0.46  0.95   6.73  6.82   0.39  0.81           0.13  1.96
# 226       May 2023  0.48  1.02   6.55  6.92   0.40  0.78           0.16  1.95
#
#      Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 222    0.39  ...        0.89   27.69  3.99  1.02  1.89   0.63   2.21
# 223    0.36  ...        0.87   27.42  4.09  1.03  1.95   0.62   2.27
# 224    0.37  ...        0.89   27.39  4.20  1.03  2.06   0.65   2.25
# 225    0.33  ...        0.95   27.29  4.23  1.03  2.11   0.68   2.30
# 226    0.37  ...        0.95   27.27  4.34  1.04  2.08   0.78   2.30
#
#      TypeScript   VBA  Visual Basic
# 222        2.77  1.02          0.59
# ...

# %%
languages.shape
# Out:
# (227, 30)

# %%
languages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           227 non-null    object
#  1   Abap           227 non-null    float64
#  2   Ada            227 non-null    float64
#  3   C/C++          227 non-null    float64
#  4   C#             227 non-null    float64
#  5   Cobol          227 non-null    float64
#  6   Dart           227 non-null    float64
#  7   Delphi/Pascal  227 non-null    float64
#  8   Go             227 non-null    float64
#  9   Groovy         227 non-null    float64
#  10  Haskell        227 non-null    float64
#  11  Java           227 non-null    float64
#  12  JavaScript     227 non-null    float64
#  13  Julia          227 non-null    float64
#  14  Kotlin         227 non-null    float64
#  15  Lua            227 non-null    float64
#  16  Matlab         227 non-null    float64
# ...

# %%
languages.describe()
# Out:
#              Abap         Ada       C/C++          C#       Cobol        Dart  \
# count  227.000000  227.000000  227.000000  227.000000  227.000000  227.000000
# mean     0.489692    0.361542    8.113348    7.496784    0.368194    0.176608
# std      0.107508    0.198476    1.774062    1.232928    0.072104    0.239022
# min      0.320000    0.090000    5.480000    4.680000    0.180000    0.000000
# 25%      0.400000    0.220000    6.800000    6.640000    0.320000    0.000000
# 50%      0.480000    0.320000    7.940000    7.200000    0.360000    0.090000
# 75%      0.560000    0.390000    8.675000    8.440000    0.405000    0.180000
# max      0.760000    1.020000   12.890000    9.940000    0.560000    0.880000
#
#        Delphi/Pascal          Go      Groovy     Haskell  ...  Powershell  \
# count     227.000000  227.000000  227.000000  227.000000  ...  227.000000
# mean        0.960661    0.476344    0.343128    0.292952  ...    0.650088
# ...

# %%
# unique values
languages.nunique()
# Out:
# Date             227
# Abap              45
# Ada               64
# C/C++            182
# C#               169
# Cobol             36
# Dart              51
# Delphi/Pascal    130
# Go                90
# Groovy            45
# Haskell           20
# Java             200
# JavaScript       141
# Julia             43
# Kotlin            64
# Lua               54
# Matlab           131
# Objective-C      159
# Perl             168
# PHP              198
# Powershell        93
# Python           208
# R                161
# Ruby             132
# Rust              81
# Scala             98
# Swift             83
# TypeScript        95
# VBA              104
# Visual Basic     170
# dtype: int64

# %%
# Column names
languages.columns
# Out:
# Index(['Date', 'Abap', 'Ada', 'C/C++', 'C#', 'Cobol', 'Dart', 'Delphi/Pascal',
#        'Go', 'Groovy', 'Haskell', 'Java', 'JavaScript', 'Julia', 'Kotlin',
#        'Lua', 'Matlab', 'Objective-C', 'Perl', 'PHP', 'Powershell', 'Python',
#        'R', 'Ruby', 'Rust', 'Scala', 'Swift', 'TypeScript', 'VBA',
#        'Visual Basic'],
#       dtype='object')

# %%
languages['Date'].unique()
# Out:
# array(['July 2004', 'August 2004', 'September 2004', 'October 2004',
#        'November 2004', 'December 2004', 'January 2005', 'February 2005',
#        'March 2005', 'April 2005', 'May 2005', 'June 2005', 'July 2005',
#        'August 2005', 'September 2005', 'October 2005', 'November 2005',
#        'December 2005', 'January 2006', 'February 2006', 'March 2006',
#        'April 2006', 'May 2006', 'June 2006', 'July 2006', 'August 2006',
#        'September 2006', 'October 2006', 'November 2006', 'December 2006',
#        'January 2007', 'February 2007', 'March 2007', 'April 2007',
#        'May 2007', 'June 2007', 'July 2007', 'August 2007',
#        'September 2007', 'October 2007', 'November 2007', 'December 2007',
#        'January 2008', 'February 2008', 'March 2008', 'April 2008',
#        'May 2008', 'June 2008', 'July 2008', 'August 2008',
#        'September 2008', 'October 2008', 'November 2008', 'December 2008',
# ...

# %%
# Check for missing values
languages.isnull().sum()
# Out:
# Date             0
# Abap             0
# Ada              0
# C/C++            0
# C#               0
# Cobol            0
# Dart             0
# Delphi/Pascal    0
# Go               0
# Groovy           0
# Haskell          0
# Java             0
# JavaScript       0
# Julia            0
# Kotlin           0
# Lua              0
# Matlab           0
# Objective-C      0
# Perl             0
# PHP              0
# Powershell       0
# Python           0
# R                0
# Ruby             0
# Rust             0
# Scala            0
# Swift            0
# TypeScript       0
# VBA              0
# Visual Basic     0
# dtype: int64

# %%
# Clening the data
languages.isnull().sum()
# Out:
# Date             0
# Abap             0
# Ada              0
# C/C++            0
# C#               0
# Cobol            0
# Dart             0
# Delphi/Pascal    0
# Go               0
# Groovy           0
# Haskell          0
# Java             0
# JavaScript       0
# Julia            0
# Kotlin           0
# Lua              0
# Matlab           0
# Objective-C      0
# Perl             0
# PHP              0
# Powershell       0
# Python           0
# R                0
# Ruby             0
# Rust             0
# Scala            0
# Swift            0
# TypeScript       0
# VBA              0
# Visual Basic     0
# dtype: int64

# %%
# Convert the Date column to datetime
languages['Date'] = pd.to_datetime(languages['Date'])
languages.head()
# Out:
#         Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0 2004-07-01  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1 2004-08-01  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2 2004-09-01  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3 2004-10-01  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4 2004-11-01  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 0    0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 1    0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2    0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 3    0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 4    0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
#    TypeScript   VBA  Visual Basic
# 0         0.0  1.43          8.50
# 1         0.0  1.45          8.51
# ...

# %%
# Boxplot of Java popularity over time
sns.boxplot(y=languages['Java'])
plt.show()
sns.boxplot(y=languages['Python'])
plt.show()
sns.boxplot(y=languages['JavaScript'])
plt.show()
sns.boxplot(y=languages['C#'])
plt.show()

# %%
sns.distplot(languages['Java'])
# Out:
# /tmp/ipykernel_29332/138946780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(languages['Java'])
# <Axes: xlabel='Java', ylabel='Density'>

# %%
# Removing the outliers
languages = languages[languages['Java'] < 25]
languages = languages[languages['Python'] < 25]
languages = languages[languages['JavaScript'] < 25]
languages = languages[languages['C#'] < 25]

# Boxplot of Java popularity over time
sns.boxplot(y=languages['Java'])
plt.show()
sns.boxplot(y=languages['Python'])
plt.show()
sns.boxplot(y=languages['JavaScript'])
plt.show()
sns.boxplot(y=languages['C#'])
plt.show()

# %%
sns.distplot(languages['Java'])
# Out:
# /tmp/ipykernel_29332/138946780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(languages['Java'])
# <Axes: xlabel='Java', ylabel='Density'>

# %%
languages.hist( bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'Abap'}>,
#         <Axes: title={'center': 'Ada'}>,
#         <Axes: title={'center': 'C/C++'}>,
#         <Axes: title={'center': 'C#'}>],
#        [<Axes: title={'center': 'Cobol'}>,
#         <Axes: title={'center': 'Dart'}>,
#         <Axes: title={'center': 'Delphi/Pascal'}>,
#         <Axes: title={'center': 'Go'}>,
#         <Axes: title={'center': 'Groovy'}>],
#        [<Axes: title={'center': 'Haskell'}>,
#         <Axes: title={'center': 'Java'}>,
#         <Axes: title={'center': 'JavaScript'}>,
#         <Axes: title={'center': 'Julia'}>,
#         <Axes: title={'center': 'Kotlin'}>],
#        [<Axes: title={'center': 'Lua'}>,
#         <Axes: title={'center': 'Matlab'}>,
#         <Axes: title={'center': 'Objective-C'}>,
#         <Axes: title={'center': 'Perl'}>,
#         <Axes: title={'center': 'PHP'}>],
#        [<Axes: title={'center': 'Powershell'}>,
# ...

# %%
languages.plot.line(x='Date', y='C#')
# Out:
# <Axes: xlabel='Date'>
