# %% [markdown]
# # Tutorial 1

# %% [markdown]
# ## What kind of data does pandas handle?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame({
    'Name':['Shahzaib Hassan','Afnan Ismail','Hashir'],
    'Age' :[21,20,-10],
    'Sex' :['Male','Female','Male']
})
df
# Out:
#               Name  Age     Sex
# 0  Shahzaib Hassan   21    Male
# 1     Afnan Ismail   20  Female
# 2           Hashir  -10    Male

# %% [markdown]
# I’m just interested in working with the data in the column Age

# %%
age = df['Age']
type(age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# I want to know the maximum Age of the passengers

# %%
age.max()
# Out:
# 21

# %% [markdown]
# I’m interested in some basic statistics of the numerical data of my data table

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   10.333333
# std    17.616280
# min   -10.000000
# 25%     5.000000
# 50%    20.000000
# 75%    20.500000
# max    21.000000

# %% [markdown]
# Many pandas operations return a DataFrame or a Series. The describe() method is an example of a pandas operation returning a pandas Series or a pandas DataFrame.

# %% [markdown]
# # Tutorial 2
# ## How do I read and write tabular data?

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.to_excel("poke.xlsx", sheet_name="pokes", index=False)

# %%
df2 = pd.read_excel('poke.xlsx',sheet_name='pokes')
df2
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# I’m interested in a technical summary of a DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# # Tutorial 3
# ## How do I select a subset of a DataFrame?
# ### 1:How do I select specific columns from a DataFrame?

# %%
attack = df['Attack']
attack.head()
# Out:
# 0     49
# 1     62
# 2     82
# 3    100
# 4     52
# Name: Attack, dtype: int64

# %%
attack.shape
# Out:
# (800,)

# %%
# To select multiple columns, use a list of column names within the selection brackets [].
attack_name = df[['Attack','Name']]
attack_name
# Out:
#      Attack                   Name
# 0        49              Bulbasaur
# 1        62                Ivysaur
# 2        82               Venusaur
# 3       100  VenusaurMega Venusaur
# 4        52             Charmander
# ..      ...                    ...
# 795     100                Diancie
# 796     160    DiancieMega Diancie
# 797     110    HoopaHoopa Confined
# 798     160     HoopaHoopa Unbound
# 799     110              Volcanion
#
# [800 rows x 2 columns]

# %% [markdown]
# ### How do I filter specific rows from a DataFrame?

# %%
attack = df[df['Attack'] > 30]
attack
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# The condition inside the selection brackets titanic["Age"] > 35 checks for which rows the Age column has a value larger than 35:

# %%
type(attack)
# Out:
# pandas.core.frame.DataFrame

# %%
# I am interested in rows which have attack 30 or 50 
attack_3050 = df[df['Attack'].isin([30,50])]
attack_3050
# Out:
#        #                   Name    Type 1   Type 2   HP  Attack  Defense  \
# 13    10               Caterpie       Bug      NaN   45      30       35
# 48    43                 Oddish     Grass   Poison   45      50       55
# 65    60                Poliwag     Water      NaN   40      50       40
# 70    65               Alakazam   Psychic      NaN   55      50       45
# 71    65  AlakazamMega Alakazam   Psychic      NaN   55      50       65
# 100   93                Haunter     Ghost   Poison   45      50       45
# 108  100                Voltorb  Electric      NaN   40      30       50
# 109  101              Electrode  Electric      NaN   60      50       70
# 112  104                 Cubone    Ground      NaN   50      50       95
# 133  124                   Jynx       Ice  Psychic   65      50       35
# 177  163               Hoothoot    Normal   Flying   60      30       30
# 178  164                Noctowl    Normal   Flying  100      50       50
# ...

# %% [markdown]
# The above is equivalent to filtering by rows for which the class is either 2 or 3 and combining the two statements with an | (or) operator:

# %%
attack_3050 = df[(df['Attack'] == 30) | (df['Attack'] == 50)]
attack_3050
# Out:
#        #                   Name    Type 1   Type 2   HP  Attack  Defense  \
# 13    10               Caterpie       Bug      NaN   45      30       35
# 48    43                 Oddish     Grass   Poison   45      50       55
# 65    60                Poliwag     Water      NaN   40      50       40
# 70    65               Alakazam   Psychic      NaN   55      50       45
# 71    65  AlakazamMega Alakazam   Psychic      NaN   55      50       65
# 100   93                Haunter     Ghost   Poison   45      50       45
# 108  100                Voltorb  Electric      NaN   40      30       50
# 109  101              Electrode  Electric      NaN   60      50       70
# 112  104                 Cubone    Ground      NaN   50      50       95
# 133  124                   Jynx       Ice  Psychic   65      50       35
# 177  163               Hoothoot    Normal   Flying   60      30       30
# 178  164                Noctowl    Normal   Flying  100      50       50
# ...

# %% [markdown]
# When combining multiple conditional statements, each condition must be surrounded by parentheses (). Moreover, you can not use or/and but need to use the or operator | and the and operator &.

# %% [markdown]
# I want to work with data for which the Type2 is known.

# %%
type2 = df[df['Type 2'].notna()]
type2
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ### How do I select specific rows and columns from a DataFrame?

# %% [markdown]
# I’m interested in the names of the pokemons having attack smaller than 35

# %%
attack_35 = df.loc[df['Attack'] < 35 , 'Name']
attack_35
# Out:
# 13               Caterpie
# 14                Metapod
# 17                 Kakuna
# 68                   Abra
# 108               Voltorb
# 121               Chansey
# 139              Magikarp
# 177              Hoothoot
# 179                Ledyba
# 187                Cleffa
# 188             Igglybuff
# 189                Togepi
# 198                Marill
# 206               Sunkern
# 217             Wobbuffet
# 230               Shuckle
# 254              Smeargle
# 257              Smoochum
# 261               Blissey
# 286             Zigzagoon
# 293                 Lotad
# 301               Wingull
# 303                 Ralts
# 307               Surskit
# 322               Azurill
# 356                Spoink
# 381                Feebas
# 394                Wynaut
# 405               Luvdisc
# 446             Kricketot
# 451                 Budew
# 457                 Burmy
# 462                Combee
# 481             Chingling
# 484               Bronzor
# ...

# %% [markdown]
# When using loc/iloc, the part before the comma is the rows you want, and the part after the comma is the columns you want to select.

# %%
df.loc[df['Attack'] > 25, ['Name', 'Generation']]
# Out:
#                       Name  Generation
# 0                Bulbasaur           1
# 1                  Ivysaur           1
# 2                 Venusaur           1
# 3    VenusaurMega Venusaur           1
# 4               Charmander           1
# ..                     ...         ...
# 795                Diancie           6
# 796    DiancieMega Diancie           6
# 797    HoopaHoopa Confined           6
# 798     HoopaHoopa Unbound           6
# 799              Volcanion           6
#
# [776 rows x 2 columns]

# %% [markdown]
# I’m interested in rows 10 till 25 and columns 3 to 5.

# %%
df.iloc[10:26,3:6]
# Out:
#     Type 2  HP  Attack
# 10     NaN  59      63
# 11     NaN  79      83
# 12     NaN  79     103
# 13     NaN  45      30
# 14     NaN  50      20
# 15  Flying  60      45
# 16  Poison  40      35
# 17  Poison  45      25
# 18  Poison  65      90
# 19  Poison  65     150
# 20  Flying  40      45
# 21  Flying  63      60
# 22  Flying  83      80
# 23  Flying  83      80
# 24     NaN  30      56
# 25     NaN  55      81

# %% [markdown]
# When selecting specific rows and/or columns with loc or iloc, new values can be assigned to the selected data. For example, to assign the name anonymous to the first 3 elements of the third column:

# %%
df.iloc[0:3,3] = 'anonymus'

# %%
df.head()
# Out:
#    #                   Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  anonymus  45      49       49       65
# 1  2                Ivysaur  Grass  anonymus  60      62       63       80
# 2  3               Venusaur  Grass  anonymus  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    Poison  80     100      123      122
# 4  4             Charmander   Fire       NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Tutorial 4
# ## How do I create plots in pandas?

# %%
air_quality = pd.read_csv("/home/mysterious/Downloads/air_quality_no2.csv", index_col=0, parse_dates=True)

air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# I want a quick visual check of the data.

# %%
air_quality.plot()
plt.show()

# %% [markdown]
# With a DataFrame, pandas creates by default one line plot for each of the columns with numeric data.

# %% [markdown]
# I want to plot only the columns of the data table with the data from Paris.

# %%
air_quality['station_paris'].plot()
plt.show()

# %% [markdown]
#  The plot() method works on both Series and DataFrame.

# %% [markdown]
# I want to visually compare the No2 values measured in London versus Paris.

# %%
air_quality.plot.scatter(x='station_paris',y = 'station_london',alpha = 0.5)
# Out:
# <Axes: xlabel='station_paris', ylabel='station_london'>

# %%
[
    method_name
    for method_name in dir(air_quality.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
air_quality.plot.box(subplots = True)
# Out:
# station_antwerp       Axes(0.125,0.11;0.227941x0.77)
# station_paris      Axes(0.398529,0.11;0.227941x0.77)
# station_london     Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
air_quality.plot.area()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality.plot.area(subplots = True)
# Out:
# array([<Axes: xlabel='datetime'>, <Axes: xlabel='datetime'>,
#        <Axes: xlabel='datetime'>], dtype=object)

# %% [markdown]
# Separate subplots for each of the data columns are supported by the subplots argument of the plot functions. The builtin options available in each of the pandas plot functions are worth reviewing.

# %% [markdown]
# I want to further customize, extend or save the resulting plot.

# %%
fig, axs = plt.subplots(figsize=(12, 4))        # Create an empty Matplotlib Figure and Axes
air_quality.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_ylabel("NO$_2$ concentration")          # Do any Matplotlib customization you like
fig.savefig("no2_concentrations.png")           # Save the Figure/Axes using the existing Matplotlib method.
plt.show()                                      # Display the plot
