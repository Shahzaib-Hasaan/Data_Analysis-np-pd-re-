# %%
# Library for excel
# !pip install openpyxl

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_excel('/media/mysterious/Resources/DataSets/Toshakhana Files 2.xlsx')
df.head()
# Out:
#             GIFTS RECORD IN TOSHAKHANA SINCE 2002\n2002  \
# 0                                                 S.No.
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 5089                                                 57
# 5090                                                 58
# 5091                                                 59
# 5092                                      DISCLAIMER: -
# 5093  The  uploaded Toshakhana  information 2002 onw...
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...
